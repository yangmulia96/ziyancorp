# %% [markdown]
# # 🚀 MoneyPrinterTurbo - Cloud GPU Video Factory (ZiyanCorp)
# Mesin otomatis pembuat video YouTube Shorts / TikTok bertenaga AI dengan akselerasi GPU Google Colab.
#
# ### 📌 Petunjuk Penggunaan:
# 1. Pastikan Runtime menggunakan GPU: **Runtime -> Change runtime type -> T4 GPU**.
# 2. Jalankan semua sel dengan menekan **Runtime -> Run all** (atau `Ctrl + F9`).
# 3. Tunggu ~2 menit sampai instalasi selesai.
# 4. Pada sel terakhir, salin **Password IP** lalu klik **Link WebUI** untuk membuka dasbor video di browser/HP!

# %%
# [1/3] INSTALASI DEPENDENSI LINUX & REPOSITORY
# !apt-get update -qq
# !apt-get install -y -qq imagemagick ffmpeg fonts-liberation
# Fix ImageMagick policy untuk render video & subtitle
# !sed -i '/<policy domain="path" rights="none" pattern="@\*"/d' /etc/ImageMagick-6/policy.xml

# Clone MoneyPrinterTurbo
# !rm -rf MoneyPrinterTurbo
# !git clone https://github.com/harry0703/MoneyPrinterTurbo.git
# %cd MoneyPrinterTurbo

# Install library python
# !pip install -q -r requirements.txt && pip install streamlit
# !npm install -g localtunnel -qq
print("✅ Instalasi dependensi selesai!")
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Cloning into 'MoneyPrinterTurbo'...
# remote: Enumerating objects: 4900, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 4900 (delta 31), reused 35 (delta 7), pack-reused 4833 (from 1)
# Receiving objects: 100% (4900/4900), 523.79 MiB | 25.69 MiB/s, done.
# Resolving deltas: 100% (3043/3043), done.
# Updating files: 100% (203/203), done.
# /content/MoneyPrinterTurbo
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 107.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 12.6 MB/s eta 0:00:00
# ...

# %%
# [2/3] KONFIGURASI API & PRESET SUBTITLE ZIYANCORP
config_content = """
gemini_api_key = "AQ.Ab8RN6IqlDYc63LpoZDn9lNdWxAzTcdtGsKYFc74ivHuJwzQdA"
gemini_model_name = "gemini-3.6-flash"
pexels_api_keys = ["F9f4KvZlReqd7klXaknvf6zPpbT00GrD62LUUojmvxUV5DwuWzCFj21h"]

[subtitle]
font_name = "LiberationSans-Bold"
font_size = 75
font_color = "#FFFFFF"
stroke_color = "#000000"
stroke_width = 4
"""

with open("config.toml", "w", encoding="utf-8") as f:
    f.write(config_content)

print("✅ Konfigurasi ZiyanCorp berhasil dimuat ke config.toml!")
# Out:
# ✅ Konfigurasi ZiyanCorp berhasil dimuat ke config.toml!

# %%
# [3/3] JALANKAN STREAMLIT & BUKA TEROWONGAN (TUNNEL)
import subprocess
import time
import urllib.request
import sys

# Dapatkan IP publik Colab untuk Tunnel Password
try:
    tunnel_password = urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip()
except Exception:
    tunnel_password = "(Lihat di output di bawah)"

# Jalankan Streamlit di background
subprocess.Popen([
    sys.executable, "-m", "streamlit", "run", "webui/Main.py",
    "--server.port", "8501",
    "--server.address", "0.0.0.0",
    "--server.enableCORS", "true",
    "--server.headless", "true"
])

time.sleep(4)

print("=" * 60)
print(f"🔑 TUNNEL PASSWORD (IP): {tunnel_password}")
print("(Jika diminta password di halaman web, masukkan angka IP di atas)")
print("=" * 60)
print("\n🌐 KLIK LINK DI BAWAH INI UNTUK BUKA DASBOR MONEYPRINTER:\n")

# !lt --port 8501
# Out:
# ...
# 🔑 TUNNEL PASSWORD (IP): 34.50.167.236
# (Jika diminta password di halaman web, masukkan angka IP di atas)
# ...
#
# 🌐 KLIK LINK DI BAWAH INI UNTUK BUKA DASBOR MONEYPRINTER:
#
# your url is: https://big-parts-stand.loca.lt
